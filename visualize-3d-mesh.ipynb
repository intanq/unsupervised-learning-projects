# %%
import open3d as o3d
import os
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
from load_3d_data import load_data
from visualization_utils import visualize

# %% [markdown]
# # Visualize Original 3D Mesh

# %%
dirname = './data/FaceTalk'
files, expressions = load_data(dirname)

# %%
len(files)
# Out:
# 1183

# %% [markdown]
# ## Visualize random 10 3D meshes

# %%
random_indexes = [130, 145, 568, 670, 1000, 450, 780, 921, 999, 932]
visualize(files, random_indexes)

# %% [markdown]
# ![image.png](attachment:image.png)
