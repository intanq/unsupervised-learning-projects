# %%
import os
import time as timer
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import open3d as o3d
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader

from load_3d_data import load_data
from visualization_utils import visualize
import train_facetalk_utils as tu
import vae
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ## Define Constants

# %%
DATA_DIR = './data'
MODEL_DIR = './models'

EPOCHS = 100
BATCH_SIZE = 16
LEARNING_RATE = 1e-3
dh = 5000
dz = 500
beta = 0.75

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Helper Functions

# %%
"""
Utility functions
"""
def reshape_vertices(inversed):
    """
    Function to reshape the inversed principal components
    to vertices
    """
    vertices = []
    for i in range(len(inversed)):
        vert = np.reshape(inversed[i], (-1, 3))
        vertices.append(vert)
    
    return vertices

def vertices_to_meshes(vertices, ori_meshes):
    """
    Function to convert vertices to meshes
    using triangles from original meshes
    """
    meshes = []
    for i in range(len(vertices)):
        triangles = np.asarray(ori_meshes[i].triangles)
        mesh = o3d.geometry.TriangleMesh(
            o3d.utility.Vector3dVector(vertices[i]), 
            o3d.utility.Vector3iVector(triangles))
        mesh.compute_vertex_normals()
        mesh.compute_triangle_normals()
        mesh.paint_uniform_color([0.5, 0.5, 0.5])
        mesh.normalize_normals()
        meshes.append(mesh)
    return meshes

# %% [markdown]
# ## Data Preparation

# %%
dirname = './data/FaceTalk'
files, expressions = load_data(dirname)
len(files)
# Out:
# 1183

# %%
"""
Split to train and test set (90:10)
"""
X_train, X_test = train_test_split(files, test_size=.1, random_state=42)
len(X_train), len(X_test)
# Out:
# (1064, 119)

# %% [markdown]
# ### Get Vertices from 3D Mesh

# %%
def get_vertices(files):
    """
    Function to get each 3d mesh file's vertices
    """
    vertices = []
    for file in files:
        vert = np.asarray(file.vertices)
        vert_reshaped = vert.reshape([1, -1])[0]
        vertices.append(vert_reshaped)
    return np.asarray(vertices)

# %%
X_train_v = get_vertices(X_train).reshape(-1, 5023, 3)
X_test_v = get_vertices(X_test).reshape(-1, 5023, 3)
X_train_v.shape, X_test_v.shape
# Out:
# ((1064, 5023, 3), (119, 5023, 3))

# %%
train_dl = DataLoader(X_train_v, batch_size=BATCH_SIZE)
test_dl = DataLoader(X_test_v, batch_size=BATCH_SIZE)

# %%
[n, dx1, dx2] = X_train_v.shape

# %% [markdown]
# ## Train Variational Autoencoder

# %%
print(f"Device: {DEVICE}")
# Out:
# Device: cuda

# %%
model = vae.VAE_FT(d_in=dx1*dx2, d_z=dz, d_h=dh).to(DEVICE)
print(model)

# Persistent file to store the model
model_path = os.path.join(MODEL_DIR, 'vae_ep100_facetalk.pth')
# Out:
# VAE_FT(
#   (encoder): Sequential(
#     (0): Linear(in_features=15069, out_features=5000, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5000, out_features=1000, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=500, out_features=5000, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=5000, out_features=15069, bias=True)
#   )
# )

# %%
"""Define loss function"""
loss_fn = tu.vae_loss

"""Define optimizer"""
optimizer = optim.Adam(
    model.parameters(), 
    lr=LEARNING_RATE
)

# %%
"""Train the Autoencoder"""

for t in range(EPOCHS):
    print(f"Epoch {t+1} out of {EPOCHS}\n ------------")
    
    start = timer.time()
    tu.train_vae(train_dl, model, loss_fn, optimizer, beta=beta)
    elapsed_time = timer.time() - start # this timing method ONLY works for CPU computation, not for GPU/cuda calls
    print(f" > Training time: {elapsed_time:>.2f} seconds")
    
    test_loss = tu.test_vae(test_dl, model, loss_fn, beta=beta)
    print(f" > Test reconstruction loss: {test_loss:>.2f}")
    
    # Save model
    torch.save(model.state_dict(), model_path)
    print(f"Model {model_path} stored!")
    
print("Done!")
# Out:
# Epoch 1 out of 100
#  ------------
# Loss: 13803.972656 [    0]/ 1064
#  > Training time: 5.30 seconds
#  > Test reconstruction loss: 800.74
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 2 out of 100
#  ------------
# Loss: 918.820129 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 705.93
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 3 out of 100
#  ------------
# Loss: 805.175293 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 600.77
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 4 out of 100
#  ------------
# Loss: 710.547974 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 414.62
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 5 out of 100
#  ------------
# Loss: 565.913086 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 379.20
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 6 out of 100
#  ------------
# Loss: 514.505493 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 332.06
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 7 out of 100
#  ------------
# Loss: 485.233765 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 323.67
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 8 out of 100
#  ------------
# Loss: 417.672302 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 267.03
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 9 out of 100
#  ------------
# Loss: 472.904053 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 331.83
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 10 out of 100
#  ------------
# Loss: 399.902679 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 285.37
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 11 out of 100
#  ------------
# Loss: 354.087036 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 243.22
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 12 out of 100
#  ------------
# Loss: 341.204773 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 240.26
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 13 out of 100
#  ------------
# Loss: 324.056702 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 214.73
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 14 out of 100
#  ------------
# Loss: 315.899597 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 262.48
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 15 out of 100
#  ------------
# Loss: 312.117615 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 284.80
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 16 out of 100
#  ------------
# Loss: 316.561981 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 212.94
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 17 out of 100
#  ------------
# Loss: 379.036316 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 201.16
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 18 out of 100
#  ------------
# Loss: 277.153503 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 155.88
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 19 out of 100
#  ------------
# Loss: 296.152893 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 139.66
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 20 out of 100
#  ------------
# Loss: 472.251648 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 166.71
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 21 out of 100
#  ------------
# Loss: 215.769714 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 175.46
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 22 out of 100
#  ------------
# Loss: 213.450592 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 224.49
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 23 out of 100
#  ------------
# Loss: 259.376251 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 151.34
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 24 out of 100
#  ------------
# Loss: 203.952484 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 120.68
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 25 out of 100
#  ------------
# Loss: 275.721008 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 145.33
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 26 out of 100
#  ------------
# Loss: 198.944885 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 172.31
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 27 out of 100
#  ------------
# Loss: 208.666153 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 158.83
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 28 out of 100
#  ------------
# Loss: 179.567596 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 141.94
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 29 out of 100
#  ------------
# Loss: 175.769928 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 206.93
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 30 out of 100
#  ------------
# Loss: 240.984650 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 138.92
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 31 out of 100
#  ------------
# Loss: 210.775726 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 124.53
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 32 out of 100
#  ------------
# Loss: 170.773651 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 122.06
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 33 out of 100
#  ------------
# Loss: 206.092972 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 138.78
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 34 out of 100
#  ------------
# Loss: 167.492462 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 107.10
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 35 out of 100
#  ------------
# Loss: 223.686035 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 154.02
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 36 out of 100
#  ------------
# Loss: 170.517914 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 108.49
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 37 out of 100
#  ------------
# Loss: 147.533020 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 98.66
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 38 out of 100
#  ------------
# Loss: 140.755768 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 106.09
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 39 out of 100
#  ------------
# Loss: 259.342834 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 165.97
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 40 out of 100
#  ------------
# Loss: 181.789948 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 218.42
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 41 out of 100
#  ------------
# Loss: 236.143402 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 140.36
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 42 out of 100
#  ------------
# Loss: 177.949860 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 154.38
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 43 out of 100
#  ------------
# Loss: 169.251526 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 138.67
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 44 out of 100
#  ------------
# Loss: 170.362122 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 159.82
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 45 out of 100
#  ------------
# Loss: 188.270111 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 165.07
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 46 out of 100
#  ------------
# Loss: 180.989365 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 169.86
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 47 out of 100
#  ------------
# Loss: 189.547913 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 137.84
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 48 out of 100
#  ------------
# Loss: 178.112717 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 209.72
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 49 out of 100
#  ------------
# Loss: 228.388611 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 308.03
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 50 out of 100
#  ------------
# Loss: 331.046204 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 138.84
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 51 out of 100
#  ------------
# Loss: 150.845810 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 346.05
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 52 out of 100
#  ------------
# Loss: 536.210083 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 241.97
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 53 out of 100
#  ------------
# Loss: 264.216858 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 167.66
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 54 out of 100
#  ------------
# Loss: 271.119812 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 139.23
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 55 out of 100
#  ------------
# Loss: 233.300583 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 141.76
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 56 out of 100
#  ------------
# Loss: 171.131836 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 156.65
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 57 out of 100
#  ------------
# Loss: 199.572845 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 204.71
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 58 out of 100
#  ------------
# Loss: 236.407349 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 208.83
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 59 out of 100
#  ------------
# Loss: 224.614090 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 148.21
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 60 out of 100
#  ------------
# Loss: 194.428162 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 142.51
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 61 out of 100
#  ------------
# Loss: 230.727371 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 139.56
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 62 out of 100
#  ------------
# Loss: 155.090912 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 163.09
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 63 out of 100
#  ------------
# Loss: 200.385208 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 139.01
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 64 out of 100
#  ------------
# Loss: 220.059464 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 158.13
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 65 out of 100
#  ------------
# Loss: 192.268677 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 148.22
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 66 out of 100
#  ------------
# Loss: 262.057861 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 132.04
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 67 out of 100
#  ------------
# Loss: 173.186966 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 130.60
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 68 out of 100
#  ------------
# Loss: 157.580276 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 155.21
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 69 out of 100
#  ------------
# Loss: 181.310669 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 565.02
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 70 out of 100
#  ------------
# Loss: 608.180481 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 206.05
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 71 out of 100
#  ------------
# Loss: 228.872833 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 175.66
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 72 out of 100
#  ------------
# Loss: 194.217636 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 144.83
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 73 out of 100
#  ------------
# Loss: 166.327316 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 145.22
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 74 out of 100
#  ------------
# Loss: 173.537659 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 269.37
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 75 out of 100
#  ------------
# Loss: 291.593201 [    0]/ 1064
#  > Training time: 3.61 seconds
#  > Test reconstruction loss: 274.28
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 76 out of 100
#  ------------
# Loss: 304.715698 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 260.63
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 77 out of 100
#  ------------
# Loss: 291.864868 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 188.52
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 78 out of 100
#  ------------
# Loss: 216.953278 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 195.20
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 79 out of 100
#  ------------
# Loss: 238.574875 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 245.51
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 80 out of 100
#  ------------
# Loss: 264.465302 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 377.52
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 81 out of 100
#  ------------
# Loss: 406.532745 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 180.25
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 82 out of 100
#  ------------
# Loss: 205.871826 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 251.16
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 83 out of 100
#  ------------
# Loss: 356.915161 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 288.16
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 84 out of 100
#  ------------
# Loss: 311.229950 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 182.00
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 85 out of 100
#  ------------
# Loss: 372.980621 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 180.45
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 86 out of 100
#  ------------
# Loss: 196.653046 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 170.55
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 87 out of 100
#  ------------
# Loss: 213.679840 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 206.74
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 88 out of 100
#  ------------
# Loss: 244.989273 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 178.94
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 89 out of 100
#  ------------
# Loss: 218.643738 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 216.39
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 90 out of 100
#  ------------
# Loss: 234.381149 [    0]/ 1064
#  > Training time: 3.60 seconds
#  > Test reconstruction loss: 165.67
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 91 out of 100
#  ------------
# Loss: 195.946472 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 302.05
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 92 out of 100
#  ------------
# Loss: 325.565125 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 198.24
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 93 out of 100
#  ------------
# Loss: 217.589371 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 182.53
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 94 out of 100
#  ------------
# Loss: 204.441040 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 179.54
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 95 out of 100
#  ------------
# Loss: 195.818207 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 184.62
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 96 out of 100
#  ------------
# Loss: 204.154419 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 244.29
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 97 out of 100
#  ------------
# Loss: 265.020355 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 186.75
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 98 out of 100
#  ------------
# Loss: 253.119186 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 201.56
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 99 out of 100
#  ------------
# Loss: 218.316467 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 202.29
# Model ./models\vae_ep100_facetalk.pth stored!
# Epoch 100 out of 100
#  ------------
# Loss: 226.144333 [    0]/ 1064
#  > Training time: 3.59 seconds
#  > Test reconstruction loss: 213.52
# Model ./models\vae_ep100_facetalk.pth stored!
# Done!
